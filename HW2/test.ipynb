# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
n_samples = 300

groups = np.random.choice(['majority', 'minority'], size=n_samples, p=[0.8, 0.2])
treatment = np.random.choice(['control', 'Neuralink_assisted'], size=n_samples)

# %%
pre_scores = np.random.normal(loc=50, scale=10, size=n_samples)
post_scores = pre_scores + np.where(treatment == 'Neuralink_assisted', 
                                    np.random.normal(7, 3, n_samples),
                                    np.random.normal(2, 3, n_samples))

df = pd.DataFrame({
    'group': groups,
    'treatment': treatment,
    'pre_score': pre_scores,
    'post_score': post_scores
})

df['gain'] = df['post_score'] - df['pre_score']

# %%
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Neuralink Learning Dataset", dataframe=df)
# Out:
# Neuralink Learning Dataset
# <table id="itables_0d282fdf_8a33_44ad_a083_5540fbae4aa8" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>group</th>
#       <th>treatment</th>
#       <th>pre_score</th>
#       <th>post_score</th>
#       <th>gain</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_0d282fdf_8a33_44ad_a083_5540fbae4aa8:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["majority", "control", 53.109076, 54.385367, 1.276292], ["minority", "Neuralink_assisted", 64.753562, 75.133257, 10.379695], ["majority", "Neuralink_assisted", 58.576596, 64.76993, 6.193334], ["majority", "Neuralink_assisted", 48.400615, 52.081037, 3.680422], ["majority", "control", 49.809838, 51.563384, 1.753546], ["majority", "control", 39.974706, 45.326594, 5.351887], ["majority", "control", 49.814869, 52.843045, 3.028176], ["minority", "Neuralink_assisted", 47.113414, 54.041038, 6.927625], ["majority", "Neuralink_assisted", 53.227186, 60.82144, 7.594254], ["majority", "Neuralink_assisted", 41.727691, 48.294609, 6.566919], ["majority", "control", 55.193465, 59.121633, 3.928168], ["minority", "Neuralink_assisted", 65.327389, 70.686812, 5.359423], ["minority", "Neuralink_assisted", 48.912399, 55.814139, 6.90174], ["majority", "Neuralink_assisted", 54.017117, 59.386843, 5.369726], ["majority", "Neuralink_assisted", 56.90144, 61.762903, 4.861463], ["majority", "control", 45.987795, 52.308147, 6.320352], ["majority", "control", 52.240925, 52.211748, -0.029177], ["majority", "Neuralink_assisted", 50.125924, 61.637903, 11.511979], ["majority", "control", 50.976761, 52.856287, 1.879526], ["majority", "control", 42.269902, 39.977577, -2.292325], ["majority", "Neuralink_assisted", 50.245102, 60.983357, 10.738256], ["majority", "Neuralink_assisted", 54.979983, 55.759812, 0.779829], ["majority", "control", 64.511436, 69.033367, 4.521931], ["majority", "Neuralink_assisted", 59.592708, 65.478386, 5.885677], ["majority", "control", 71.531825, 72.193274, 0.66145], ["majority", "Neuralink_assisted", 42.326524, 46.993074, 4.66655], ["majority", "control", 58.723206, 59.366287, 0.643081], ["majority", "Neuralink_assisted", 51.83342, 64.090231, 12.256811], ["majority", "control", 71.898029, 69.146321, -2.751708], ["majority", "control", 41.917017, 46.198261, 4.281244], ["majority", "control", 41.602782, 45.960182, 4.3574], ["majority", "Neuralink_assisted", 44.006074, 47.618918, 3.612845], ["majority", "control", 28.761043, 27.860114, -0.900928], ["minority", "control", 44.74245, 46.599316, 1.856866], ["minority", "Neuralink_assisted", 42.408673, 45.74229, 3.333617], ["minority", "Neuralink_assisted", 51.503938, 60.642933, 9.138995], ["majority", "control", 53.41756, 59.927755, 6.510195], ["majority", "control", 68.761708, 73.393795, 4.632087], ["majority", "Neuralink_assisted", 59.504238, 68.637118, 9.13288], ["majority", "Neuralink_assisted", 44.230963, 52.563753, 8.33279], ["majority", "Neuralink_assisted", 41.015853, 46.932955, 5.917102], ["majority", "Neuralink_assisted", 54.919192, 65.397181, 10.477989], ["majority", "Neuralink_assisted", 36.797668, 40.554478, 3.75681], ["minority", "control", 68.314588, 68.268635, -0.045953], ["majority", "Neuralink_assisted", 61.794401, 70.573705, 8.779304], ["majority", "control", 45.308243, 46.464943, 1.156699], ["majority", "control", 32.868655, 40.261714, 7.39306], ["majority", "control", 63.538724, 67.461252, 3.922529], ["majority", "Neuralink_assisted", 48.854602, 58.626683, 9.772081], ["majority", "control", 62.378163, 66.095911, 3.717748], ["minority", "control", 34.055723, 40.25379, 6.198066], ["majority", "Neuralink_assisted", 44.00625, 54.153277, 10.147028], ["minority", "control", 50.052437, 52.231328, 2.178891], ["minority", "control", 50.469806, 50.528996, 0.05919], ["majority", "Neuralink_assisted", 45.499345, 47.829458, 2.330112], ["minority", "control", 56.228499, 59.408955, 3.180456], ["majority", "control", 39.323796, 44.009375, 4.68558], ["majority", "control", 48.576205, 52.481721, 3.905515], ["majority", "Neuralink_assisted", 51.202956, 51.957168, 0.754212], ["majority", "Neuralink_assisted", 55.144388, 67.233757, 12.089369], ["majority", "Neuralink_assisted", 57.116149, 64.749201, 7.633052], ["majority", "control", 38.753579, 41.346378, 2.592799], ["minority", "control", 34.658858, 42.884641, 8.225783], ["majority", "Neuralink_assisted", 62.776768, 70.97417 ...

# %%
df.head()
# Out:
#       group           treatment  pre_score  post_score       gain
# 0  majority             control  53.109076   54.385367   1.276292
# 1  minority  Neuralink_assisted  64.753562   75.133257  10.379695
# 2  majority  Neuralink_assisted  58.576596   64.769930   6.193334
# 3  majority  Neuralink_assisted  48.400615   52.081037   3.680422
# 4  majority             control  49.809838   51.563384   1.753546

# %%
df.tail()
# Out:
#         group           treatment  pre_score  post_score      gain
# 295  majority  Neuralink_assisted  47.272764   51.062510  3.789746
# 296  majority  Neuralink_assisted  23.031134   25.454558  2.423424
# 297  majority  Neuralink_assisted  49.457051   54.381327  4.924276
# 298  majority             control  47.690655   50.392012  2.701358
# 299  majority             control  56.962064   54.294377 -2.667687

# %%
def cohens_d(group1, group2):
    diff_mean = group1.mean() - group2.mean()
    pooled_std = np.sqrt(((group1.std() ** 2) + (group2.std() ** 2)) / 2)
    return diff_mean / pooled_std

results = []
for g in df['group'].unique():
    control_group = df[(df['group'] == g) & (df['treatment'] == 'control')]['gain']
    neuralink_group = df[(df['group'] == g) & (df['treatment'] == 'Neuralink_assisted')]['gain']
    d = cohens_d(neuralink_group, control_group)
    results.append({'group': g, 'effect_size (Cohen\'s d)': round(d, 3)})

effect_size_df = pd.DataFrame(results)
effect_size_df

tools.display_dataframe_to_user(name="Effect Size by Group (Neuralink)", dataframe=effect_size_df)
# Out:
# [{'group': 'majority', "effect_size (Cohen's d)": 1.514}, {'group': 'minority', "effect_size (Cohen's d)": 2.006}]
# Effect Size by Group (Neuralink)
# <table id="itables_8f22606a_7368_4a39_9782_716e256de43d" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>group</th>
#       <th>effect_size (Cohen's d)</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_8f22606a_7368_4a39_9782_716e256de43d:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["majority", 1.514], ["minority", 2.006]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
